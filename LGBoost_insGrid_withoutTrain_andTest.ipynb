# %%
pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\users\elcot\.eclipse\anaconda\lib\site-packages (4.1.0)
# Requirement already satisfied: scipy in c:\users\elcot\.eclipse\anaconda\lib\site-packages (from lightgbm) (1.10.0)
# Requirement already satisfied: numpy in c:\users\elcot\.eclipse\anaconda\lib\site-packages (from lightgbm) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import lightgbm as lg
print(lg.__version__)
# Out:
# 4.1.0

# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset.iloc[:, [0, 1, 2, 4, 5]]

# %%
dep=dataset.iloc[:, [3]]

# %%
from sklearn.model_selection import GridSearchCV
from lightgbm import LGBMRegressor

paramgrid = {'max_depth': [5,10],
             'n_estimators': [25,100,50], 'num_leaves': [20, 31, 40]}
grid=GridSearchCV(LGBMRegressor(), paramgrid, refit=True, verbose=3, n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000341 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 313
# [LightGBM] [Info] Number of data points in the train set: 1338, number of used features: 5
# [LightGBM] [Info] Start training from score 13270.422260
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# GridSearchCV(estimator=LGBMRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [5, 10], 'n_estimators': [25, 100, 50],
#                          'num_leaves': [20, 31, 40]},
#              verbose=3)

# %%
bestParams=grid.best_params_
rscore=grid.best_score_

# %%
print(" The best parameter {} ".format(bestParams))
print("The R2Score {} ".format(rscore))
# Out:
#  The best parameter {'max_depth': 5, 'n_estimators': 50, 'num_leaves': 20}
# The R2Score 0.8569413314088464

# %%
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.418897      0.424235         0.012501    1.169332e-02
# 1        0.096881      0.006252         0.009376    7.655707e-03
# 2        0.090629      0.006250         0.009375    7.654850e-03
# 3        0.193762      0.007658         0.012501    6.250358e-03
# 4        0.228140      0.007657         0.009375    7.654656e-03
# 5        0.231266      0.006250         0.003125    6.249619e-03
# 6        0.109383      0.009882         0.009375    7.654695e-03
# 7        0.140632      0.000003         0.015629    4.967810e-06
# 8        0.134385      0.007655         0.012501    6.250310e-03
# 9        0.065628      0.006253         0.009376    7.655590e-03
# 10       0.078129      0.000002         0.015627    8.714517e-07
# 11       0.096880      0.011695         0.012501    6.250477e-03
# 12       0.193557      0.013299         0.015623    5.471382e-06
# 13       0.271895      0.012502         0.012502    6.250978e-03
# 14       0.303145      0.007658         0.012502    6.250882e-03
# 15       0.103439      0.015125         0.012501    1.169352e-02
# 16       0.153135      0.011695         0.006252    7.657109e-03
# 17       0.168762      0.006250         0.012502    6.250930e-03
#
#    param_max_depth param_n_estimators param_num_leaves  \
# 0                5                 25               20
# 1                5                 25               31
# 2                5                 25               40
# 3                5                100               20
# 4                5                100               31
# 5                5                100               40
# 6                5                 50               20
# 7                5                 50               31
# 8                5                 50               40
# 9               10                 25               20
# 10              10                 25               31
# 11              10                 25               40
# 12              10                100               20
# 13              10                100               31
# 14              10                100               40
# 15              10                 50               20
# 16              10                 50               31
# 17              10                 50               40
#
#                                                params  split0_test_score  \
# 0   {'max_depth': 5, 'n_estimators': 25, 'num_leav...           0.876924
# 1   {'max_depth': 5, 'n_estimators': 25, 'num_leav...           0.877259
# 2   {'max_depth': 5, 'n_estimators': 25, 'num_leav...           0.877259
# 3   {'max_depth': 5, 'n_estimators': 100, 'num_lea...           0.872285
# 4   {'max_depth': 5, 'n_estimators': 100, 'num_lea...           0.873535
# 5   {'max_depth': 5, 'n_estimators': 100, 'num_lea...           0.873535
# 6   {'max_depth': 5, 'n_estimators': 50, 'num_leav...           0.876830
# 7   {'max_depth': 5, 'n_estimators': 50, 'num_leav...           0.879432
# 8   {'max_depth': 5, 'n_estimators': 50, 'num_leav...           0.879432
# 9   {'max_depth': 10, 'n_estimators': 25, 'num_lea...           0.876396
# 10  {'max_depth': 10, 'n_estimators': 25, 'num_lea...           0.872401
# 11  {'max_depth': 10, 'n_estimators': 25, 'num_lea...           0.872163
# 12  {'max_depth': 10, 'n_estimators': 100, 'num_le...           0.862959
# 13  {'max_depth': 10, 'n_estimators': 100, 'num_le...           0.862049
# 14  {'max_depth': 10, 'n_estimators': 100, 'num_le...           0.859007
# 15  {'max_depth': 10, 'n_estimators': 50, 'num_lea...           0.871343
# 16  {'max_depth': 10, 'n_estimators': 50, 'num_lea...           0.869225
# 17  {'max_depth': 10, 'n_estimators': 50, 'num_lea...           0.869282
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.808301           0.883956           0.846301
# 1            0.807882           0.883846           0.844253
# 2            0.807882           0.883846           0.844253
# 3            0.797903           0.883365           0.845406
# 4            0.798158           0.885281           0.844743
# 5            0.798158           0.885281           0.844743
# 6            0.806607           0.891248           0.847561
# 7            0.805027           0.890906           0.845394
# 8            0.805027           0.890906           0.845394
# 9            0.807036           0.882365           0.843170
# 10           0.801934           0.882600           0.841044
# 11           0.801259           0.882621           0.839829
# 12           0.790263           0.876256           0.841176
# 13           0.787063           0.878208           0.836449
# 14           0.783118           0.878488           0.835926
# 15           0.802695           0.887049           0.844106
# 16           0.796852           0.888157           0.839929
# 17           0.797612           0.888642           0.838478
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.861413         0.855379        0.026892                4
# 1            0.859330         0.854514        0.027132                5
# 2            0.859330         0.854514        0.027132                5
# 3            0.856031         0.850998        0.029585               11
# 4            0.855125         0.851368        0.030102                9
# 5            0.855125         0.851368        0.030102                9
# 6            0.862461         0.856941        0.029067                1
# 7            0.860792         0.856310        0.030002                2
# 8            0.860792         0.856310        0.030002                2
# 9            0.859400         0.853673        0.027047                7
# 10           0.855865         0.850769        0.028237               12
# 11           0.855373         0.850249        0.028506               14
# 12           0.850653         0.844261        0.029460               16
# 13           0.848552         0.842464        0.030996               17
# 14           0.848376         0.840983        0.032125               18
# 15           0.860142         0.853067        0.028832                8
# 16           0.858234         0.850479        0.031043               13
# 17           0.856551         0.850113        0.030936               15

# %%
age=int(input("Age : "))
bmi=int(input("Bmi : "))
children=int(input("Children : "))
male=int(input("Sex_Male 0 or 1 : "))
smoker=int(input("Smoker_Yes 0 or 1 : "))
# Out:
# Age : 30
# Bmi : 29
# Children : 2
# Sex_Male 0 or 1 : 0
# Smoker_Yes 0 or 1 : 0

# %%
futurePred=grid.predict([[age,bmi,children,male,smoker]])

# %%
print("Future Predictions : {} ".format(futurePred))
# Out:
# Future Predictions : [6437.82596397]

# %%
import pickle
filename="finalModel_LGBoost.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("finalModel_LGBoost.sav",'rb'))
result=loaded_model.predict([[30,29,2,0,0]])
result
# Out:
# array([6437.82596397])

# %%
prediction = [[30, 22, 1, 1, 0]]
prediction_df = pd.DataFrame(prediction, columns=['age', 'bmi', 'children', 'sex_male', 'smoker_yes'])

# %%
result2 = loaded_model.predict(prediction_df)
print(result2)
# Out:
# [5934.87896891]
