# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400         0           1
# 1   18  33.770         1   1725.55230         1           0
# 2   28  33.000         3   4449.46200         1           0
# 3   33  22.705         0  21984.47061         1           0
# 4   32  28.880         0   3866.85520         1           0

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dep=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
             'splitter':['best', 'random'],
              'max_features':['sqrt','log2']}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
rscore=grid.best_score_

bestParams=grid.best_params_
re=grid.cv_results_

# %%
print("The hyper tuning parameter {} ".format(bestParams),rscore)
# Out:
# The hyper tuning parameter {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}  0.7272879987457965

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.028105      0.006241         0.006250    7.654188e-03
# 1        0.015613      0.000021         0.015627    1.919233e-06
# 2        0.034360      0.006247         0.009381    7.659292e-03
# 3        0.028123      0.006256         0.015623    9.882572e-03
# 4        0.028120      0.011698         0.012505    6.252289e-03
# 5        0.021877      0.007655         0.015626    9.880761e-03
# 6        0.034378      0.011698         0.012495    1.169058e-02
# 7        0.015625      0.000003         0.015626    7.599534e-07
# 8        0.071879      0.012500         0.012502    6.250883e-03
# 9        0.050002      0.011693         0.009377    1.250222e-02
# 10       0.068747      0.007654         0.012506    6.253219e-03
# 11       0.070225      0.025987         0.009376    7.655279e-03
# 12       0.054296      0.039363         0.007684    4.990157e-03
# 13       0.018752      0.006251         0.012502    6.251170e-03
# 14       0.024999      0.007656         0.018751    1.169197e-02
# 15       0.022775      0.007111         0.012497    6.248324e-03
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.635208
# 1   {'criterion': 'squared_error', 'max_features':...           0.637996
# 2   {'criterion': 'squared_error', 'max_features':...           0.729991
# 3   {'criterion': 'squared_error', 'max_features':...           0.713969
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.765359
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.660421
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.731202
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.675478
# 8   {'criterion': 'absolute_error', 'max_features'...           0.744583
# 9   {'criterion': 'absolute_error', 'max_features'...           0.711026
# 10  {'criterion': 'absolute_error', 'max_features'...           0.651039
# 11  {'criterion': 'absolute_error', 'max_features'...           0.705229
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.761957
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.749286
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.604478
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.632741
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.640188           0.593151           0.643818
# 1            0.593985           0.722460           0.557135
# 2            0.697925           0.713761           0.759139
# 3            0.604309           0.730337           0.694665
# 4            0.610485           0.739025           0.686550
# 5            0.507878           0.648428           0.676997
# 6            0.634160           0.629553           0.669414
# 7            0.630399           0.714373           0.661433
# 8            0.472227           0.730445           0.752680
# 9            0.625806           0.757107           0.665639
# 10           0.544852           0.718113           0.730475
# 11           0.647581           0.683629           0.702172
# 12           0.588374           0.663932           0.687955
# 13           0.579917           0.709158           0.662454
# 14           0.644910           0.698235           0.619543
# 15           0.597706           0.752957           0.684082
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.720246         0.646522        0.041132               14
# 1            0.606272         0.623570        0.055813               16
# 2            0.735625         0.727288        0.020671                1
# 3            0.495578         0.647772        0.087693               13
# 4            0.698889         0.700062        0.052896                2
# 5            0.687729         0.636291        0.065608               15
# 6            0.685923         0.670050        0.037202               10
# 7            0.690806         0.674498        0.028186                8
# 8            0.707767         0.681540        0.105761                5
# 9            0.644415         0.680799        0.047570                6
# 10           0.739489         0.676794        0.072927                7
# 11           0.586154         0.664953        0.044423               11
# 12           0.762592         0.692962        0.065445                3
# 13           0.732265         0.686616        0.060808                4
# 14           0.677497         0.648933        0.034937               12
# 15           0.693814         0.672260        0.053360                9

# %%
age=int(input("Age : "))
bmi=int(input("Bmi : "))
children=int(input("Children : "))
male=int(input("Sex_Male 0 or 1 : "))
smoker=int(input("Smoker_Yes 0 or 1 : "))
# Out:
# Age : 30
# Bmi : 29
# Children : 3
# Sex_Male 0 or 1 : 0
# Smoker_Yes 0 or 1 : 1

# %%
futurePred=grid.predict([[age,bmi,children,male,smoker]])
# Out:
# C:\Users\ELCOT\.eclipse\anaconda\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
print("Future Predictions : {} ".format(futurePred))
# Out:
# Future Predictions : [19521.9682]
