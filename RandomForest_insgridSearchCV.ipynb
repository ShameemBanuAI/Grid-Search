# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
depen=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,depen,test_size=1/3,random_state=0)

# %%
# Using gridsearchcv
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

param_grid={'criterion' : ['absolute_error', 'squared_error', 'friedman_mse', 'poisson'],
            'n_estimators': [10,100],'max_features':['auto', 'sqrt', 'log2']}

grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\ELCOT\.eclipse\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 40 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ELCOT\.eclipse\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ELCOT\.eclipse\anaconda\lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ELCOT\.eclipse\anaconda\lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ELCOT\.eclipse\anaconda\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\ELCOT\.eclipse\anaconda\lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.78397429 0.8037747  0.77913218 0.79981902
#         nan        nan 0.7728607  0.80098364 0.78427375 0.80113733
#         nan        nan 0.77658065 0.80267711 0.77976324 0.80572916
#         nan        nan 0.79075327 0.80093504 0.77578424 0.8039317 ]
#   warnings.warn(
# C:\Users\ELCOT\.eclipse\anaconda\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'squared_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_pred=grid.predict(x_test)

from sklearn.metrics import r2_score
rscore=r2_score(y_test,grid_pred)

print("the R2score value of best parameter:{} ".format(grid.best_params_),rscore)
# Out:
# the R2score value of best parameter:{'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100}  0.8691845769275587

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001855      0.003114         0.000000        0.000000
# 1        0.001593      0.003186         0.000000        0.000000
# 2        0.282888      0.064875         0.025544        0.012208
# 3        2.557614      0.205859         0.046877        0.009885
# 4        0.324138      0.080461         0.019678        0.008096
# 5        2.825218      0.233474         0.062505        0.032774
# 6        0.000000      0.000000         0.000000        0.000000
# 7        0.000000      0.000000         0.000000        0.000000
# 8        0.181255      0.037758         0.025002        0.018753
# 9        1.584754      0.474437         0.084379        0.067461
# 10       0.131260      0.015931         0.009371        0.007651
# 11       0.914407      0.046813         0.031253        0.000002
# 12       0.000000      0.000000         0.000000        0.000000
# 13       0.006251      0.007656         0.000000        0.000000
# 14       0.096878      0.018222         0.012501        0.006251
# 15       1.120666      0.215881         0.050002        0.006250
# 16       0.140633      0.013978         0.021883        0.021208
# 17       1.064900      0.070053         0.046878        0.009881
# 18       0.000000      0.000000         0.000000        0.000000
# 19       0.003124      0.006249         0.000000        0.000000
# 20       0.161740      0.053227         0.012501        0.006251
# 21       1.228171      0.032176         0.050005        0.006250
# 22       0.128129      0.011693         0.015628        0.000002
# 23       1.143951      0.171276         0.046878        0.026145
#
#    param_criterion param_max_features param_n_estimators  \
# 0   absolute_error               auto                 10
# 1   absolute_error               auto                100
# 2   absolute_error               sqrt                 10
# 3   absolute_error               sqrt                100
# 4   absolute_error               log2                 10
# 5   absolute_error               log2                100
# 6    squared_error               auto                 10
# 7    squared_error               auto                100
# 8    squared_error               sqrt                 10
# 9    squared_error               sqrt                100
# 10   squared_error               log2                 10
# 11   squared_error               log2                100
# 12    friedman_mse               auto                 10
# 13    friedman_mse               auto                100
# 14    friedman_mse               sqrt                 10
# 15    friedman_mse               sqrt                100
# 16    friedman_mse               log2                 10
# 17    friedman_mse               log2                100
# 18         poisson               auto                 10
# 19         poisson               auto                100
# 20         poisson               sqrt                 10
# 21         poisson               sqrt                100
# 22         poisson               log2                 10
# 23         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'absolute_error', 'max_features'...                NaN
# 1   {'criterion': 'absolute_error', 'max_features'...                NaN
# 2   {'criterion': 'absolute_error', 'max_features'...           0.805607
# 3   {'criterion': 'absolute_error', 'max_features'...           0.805607
# 4   {'criterion': 'absolute_error', 'max_features'...           0.799373
# 5   {'criterion': 'absolute_error', 'max_features'...           0.804747
# 6   {'criterion': 'squared_error', 'max_features':...                NaN
# 7   {'criterion': 'squared_error', 'max_features':...                NaN
# 8   {'criterion': 'squared_error', 'max_features':...           0.769747
# 9   {'criterion': 'squared_error', 'max_features':...           0.807830
# 10  {'criterion': 'squared_error', 'max_features':...           0.787116
# 11  {'criterion': 'squared_error', 'max_features':...           0.806611
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.788360
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.810194
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.789620
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.814390
# 18  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.780511
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.802143
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.769776
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.809779
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.724147           0.826275           0.818406
# 3            0.776842           0.838801           0.834950
# 4            0.721433           0.834094           0.786436
# 5            0.769205           0.834722           0.822617
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.759408           0.806429           0.802104
# 9            0.765401           0.834458           0.834374
# 10           0.753992           0.823123           0.799893
# 11           0.778391           0.838599           0.823689
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.764485           0.822960           0.787136
# 15           0.771689           0.840186           0.829265
# 16           0.770009           0.816454           0.790765
# 17           0.779183           0.837616           0.837234
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.775304           0.820524           0.815278
# 21           0.774950           0.835926           0.828578
# 22           0.733007           0.833881           0.798997
# 23           0.774909           0.837084           0.836909
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.745436         0.783974        0.041249               11
# 3            0.762674         0.803775        0.030387                3
# 4            0.754325         0.779132        0.038545               13
# 5            0.767805         0.799819        0.027292                8
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.726615         0.772861        0.029364               16
# 9            0.762855         0.800984        0.031630                6
# 10           0.757245         0.784274        0.026111               10
# 11           0.758396         0.801137        0.029279                5
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.719962         0.776581        0.033921               14
# 15           0.762051         0.802677        0.030923                4
# 16           0.731968         0.779763        0.028085               12
# 17           0.760222         0.805729        0.031177                1
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.762150         0.790753        0.023019                9
# 21           0.763078         0.800935        0.028630                7
# 22           0.743260         0.775784        0.036981               15
# 23           0.760978         0.803932        0.031331                2

# %%
age=int(input("Age : "))
bmi=float(input("Bmi : "))
children=int(input("Children : "))
sexMale=int(input("Sex Male 0 or 1 :" ))
smoker=int(input("Smoker 0 or 1 :"))
# Out:
# Age : 25
# Bmi : 20
# Children : 0
# Sex Male 0 or 1 :1
# Smoker 0 or 1 :0

# %%
futurePred=grid.predict([[age,bmi,children,sexMale,smoker]])
print("Future Predictions : {} ".format(futurePred))
# Out:
# Future Predictions : [3287.5435087]
# C:\Users\ELCOT\.eclipse\anaconda\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
